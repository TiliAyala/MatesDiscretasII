# %% [markdown]
# # **ALGORITMO DE EUCLIDES**
#
# Por Iván Felipe Ayala Rengifo
#
# Este código aprovecha el Algoritmo de Euclides para dar con un código eficiente y veloz que calcule el MCD entre dos números.

# %%
import sys


#print(60%207)

def Euclides (a, b, lista):

  r = int(a%b)
  #print(r)

  if r > 0:
    lista.append(r)
    Euclides(b, r, lista)
  else:
    return 1


  




print("Ingresa a Continuación dos números para hallar su MCD mediante el algoritmo de Euclides.\nEscribe un número por cada línea:\n ")
Input1 = int(input())
Input2 = int(input())

if Input1 < Input2:
  a = int(Input2)
  b = int(Input1)
elif Input1 > Input2:
  a = int(Input1)
  b = int(Input2)
else:
  sys.exit("Los números ingresados son iguales. El MCD es "+ str(Input1))

RestoLog = []

MCD = Euclides(a, b, RestoLog)

print("El MCD entre "+ str(a)+ " y " + str(b)+ " es "+ str(RestoLog[(len(RestoLog))-1]))
# Out:
# Ingresa a Continuación dos números para hallar su MCD mediante el algoritmo de Euclides.
# Escribe un número por cada línea:
#
# 231
# 49
# El MCD entre 231 y 49 es 7
